# %% [markdown]
# # Análisis de una Noticia en Internet
#
# En este análisis, se trabaja con una noticia obtenida de una página web. Se extrae el contenido HTML y se filtra para llevar a cabo un análisis lingüístico. La noticia seleccionada lleva el título "Lluvias del fin de semana provocaron afectaciones en Golfito, Esparza, Quepos y Garabito" y se almacena en la variable `text`.
#
# ## Descripción del Análisis
#
# El objetivo de este análisis es utilizar herramientas de procesamiento de lenguaje natural (NLP) y expresiones regulares para comprender mejor el contenido de la noticia. A continuación, se detallan los pasos clave del proceso:
#
# 1. **Extracción de HTML**: Se obtiene el contenido completo de la página web, incluyendo el formato HTML.
#
# 2. **Filtrado de Contenido**: Se realiza un filtrado para extraer únicamente el texto relevante de la noticia, eliminando etiquetas y elementos HTML innecesarios.
#
# 3. **Identificación de Oraciones**: Se utilizan expresiones regulares para identificar y extraer las oraciones clave de la noticia.
#
# 4. **Identificación de Tokens**: Se definen tokens como las palabras dentro de las oraciones. Estos tokens se extraen mediante el uso de expresiones regulares.
#
# 5. **Análisis de Frecuencia**: Se analiza la frecuencia de cada término en el vocabulario para comprender mejor los temas clave de la noticia.
#
# ## Noticia Seleccionada
#
# La noticia seleccionada para este análisis lleva el siguiente título:
#
# **"Lluvias del fin de semana provocaron afectaciones en Golfito, Esparza, Quepos y Garabito"**
#
# Esta noticia es fundamental para llevar a cabo el análisis lingüístico y explorar su contenido en detalle.
#
# ## Código Fuente
#
# A continuación, se muestra el código utilizado para realizar el análisis:

# %%
import requests
from bs4 import BeautifulSoup

# copiamos el url de la noticia, puede ser cualquier noticia
url = "https://delfino.cr/2023/09/lluvias-del-fin-de-semana-provocaron-afectaciones-en-golfito-esparza-quepos-y-garabito"
response = requests.get(url)

soup = BeautifulSoup(response.content, "html.parser")

# se guardo el codigo html en una variable text
text = soup.find("html")

# se imprime la variable text para ver el codigo en html
print(text)
# Out:
# <html lang="es"><head><script>_atrk_opts = { atrk_acct:"ymNhu1WyR620WR", domain:"delfino.cr",dynamic: true};
#       (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://certify-js.alexametrics.com/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();</script><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="application/javascript"></script><meta charset="utf-8" class="next-head"/><meta class="next-head" content="initial-scale=1.0, width=device-width" name="viewport"/><link class="next-head" href="/static/favicon.ico" rel="icon" type="image/x-icon"/><link class="next-head" href="https://fonts.googleapis.com/css?family=Roboto+Slab:700|Roboto:400,500,700" rel="stylesheet"/><meta class="next-head" content="#000000" name="theme-color"/><meta class="next-head" content="#000000" name="msapplication-navbutton-color"/><meta class="next-head" content="yes" name="apple-mobile-web-app-capable"/><meta class="next-head" content="black" name="apple-mobile-web-app-status-bar-style"/><title class="next-head">Lluvias del fin de semana provocaron afectaciones en Golfito, Esparza, Quepos y Garabito - Delfino.cr</title><meta class="next-head" content="El país se encuentra en la etapa más intensa de la época lluviosa." name="description"/><meta class="next-head" content="https://delfino.cr/2023/09/lluvias-del-fin-de-semana-provocaron-afectaciones-en-golfito-esparza-quepos-y-garabito" property="og:url"/><meta class="next-head" content="website" property="og:type"/><meta class="next-head" content="Lluvias del fin de semana provocaron afectaciones en Golfito, Esparza, Quepos y Garabito" property="og:title"/><meta class="next-head" content="El país se encuentra en la etapa más intensa de la época lluviosa." property="og:description"/><meta class="next-head" content="https://d1qqtien6gys07.cloudfront.net/wp-content/uploads/2023/09/IMN.jpg" property="og:image"/><meta class="next-head" content="summary_large_image" name="twitter:card"/><meta class="next-head" content="Lluvias del fin de semana provocaron afectaciones en Golfito, Esparza, Quepos y Garabito" name="twitter:title"/><meta class="next-head" content="https://d1qqtien6gys07.cloudfront.net/wp-content/uploads/2023/09/IMN.jpg" name="twitter:image"/><meta class="next-head" content="@delfinocrc" name="twitter:site"/><meta class="next-head" content="El país se encuentra en la etapa más intensa de la época lluviosa." name="twitter:description"/><meta class="next-head" content="@delfinocrc" name="twitter:creator"/><link class="next-head" href="https://delfino.cr/feed" rel="alternate" title="Delfino.cr Feed" type="application/rss+xml"/><link class="next-head" href="https://delfino.cr/2023/09/lluvias-del-fin-de-semana-provocaron-afectaciones-en-golfito-esparza-quepos-y-garabito" rel="canonical"/><script async="" charset="utf-8" class="next-head" src="https://platform.twitter.com/widgets.js"></script><link as="script" href="/_next/static/agYfG8ZIn~AjU_hy7u5BE/pages/_post.js" rel="preload"/><link as="script" href="/_next/static/agYfG8ZIn~AjU_hy7u5BE/pages/_app.js" rel="preload"/><link as="script" href="/_next/static/runtime/webpack-0bb2a7e9ccb41a2a5d6b.js" rel="preload"/><link as="script" href="/_next/static/chunks/commons.935191bf8200065d8905.js" rel="preload"/><link as="script" href="/_next/static/runtime/main-d1b8e7abd637fc72076d.js" rel="preload"/></head><body><div id="__next"><style data-emotion-css="1004m32">html{position:relative;min-height:100%;}body{font-family:Roboto,helvetica,arial,sans-serif;margin:0;font-size:16px;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;padding-bottom:200px !important;color:#111111;width:100%;}@media (max-width:768px){body{padding-bottom:350px !important;}}iframe{border:none;}figure{margin-left:0;margin-right:0;}button{font-family:Roboto,helvetica,arial,sans-serif;}button:focus{outline:none;}textarea,input.text,input[type="text"],input[type="password"],input[type="button"],input[type="submit"],.input-checkbox{font ...
# <p>La<strong> Comisión Nacional de Emergencias</strong> (CNE) informó que las lluvias del fin de semana dejaron inundaciones en parte de la vertiente del pacífico, siendo los cantones de Golfito, Esparza, Quepos y Garabito los de más afectación.</p>
# <p>La mayoría de las emergencias atendidas por los comités de emergencia se debieron al desbordamiento de quebradas y alcantarillas que provocaron la llegada de agua a las viviendas y locales. En total se presentaron <strong>33 eventos.</strong></p>
# <p>Según indicó el presidente ejecutivo de la CNE, <strong>Alejandro Picado Eduarte, </strong>otras de las afectaciones fueron provocadas por las altas mareas presentadas en Puntarenas donde se reportaron incidentes en los cantones de Esparza en Caldera; Quepos en El Cocal; y Golfito en Pavones.</p>
# <p>El jerarca recordó que, de acuerdo con el Instituto Meteorológico Nacional (IMN), el país se encuentra <strong>en la etapa más intensa de la época lluviosa</strong>, por lo que es común que se den lluvias súbitas que desencadenen cabezas de agua y deslizamientos en algunas zonas del territorio nacional.</p>
# <div id="in-content"></div></div><style data-emotion-css="1l5l51w">.css-1l5l51w{width:100%;max-width:720px;padding:20px 0;}.css-1l5l51w a{color:black;cursor:pointer !important;}.css-1l5l51w a:hover{-webkit-text-decoration:none;text-decoration:none;}@media (max-width:1100px){.css-1l5l51w{margin-left:auto;margin-right:auto;}}</style><div class="css-1l5l51w"><style data-emotion-css="pyeond">.css-pyeond{height:1px;width:100%;border-bottom:1px solid rgba(0,0,0,0.2);}</style><div class="css-pyeond"></div><style data-emotion-css="3swnml">.css-3swnml{width:100%;max-width:720px;margin:0;}.css-3swnml a{color:black;-webkit-text-decoration:none;text-decoration:none;}@media (max-width:1100px){.css-3swnml{margin:auto;}}@media (max-width:769px){.css-3swnml{margin:0;}}</style><div class="css-3swnml"><a href="/autor/alonso-martinez"><style data-emotion-css="iydxj">.css-iydxj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;padding:20px 0;}</style><div class="css-iydxj"><style data-emotion-css="uaok1j">.css-uaok1j{max-width:100px;border-radius:50%;margin-right:30px;}@media (max-width:768px){.css-uaok1j{margin-right:20px;}}</style><img alt="Delfino CR" class="css-uaok1j" src="https://d1qqtien6gys07.cloudfront.net/wp-content/uploads/2019/10/Alonso-150x150.jpg"/><style data-emotion-css="n0emup">.css-n0emup{text-align:left;font-size:14px;}.css-n0emup p{margin-bottom:0;color:#7f7f7f;}</style><div class="css-n0emup"><style data-emotion-css="z2j2md">.css-z2j2md{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;cursor:inherit;}.css-z2j2md svg{top:-1px;margin-left:3px;-webkit-transition:all 0.4s ease;transition:all 0.4s ease;}@media (max-width:768px){.css-z2j2md svg{width:20px;}}.css-z2j2md:hover svg{-webkit-transform:translate(10px);-ms-transform:translate(10px);transform:translate(10px);}</style><div class="css-z2j2md"><style data-emotion-css="134ap8u">.css-134ap8u{font-family:Roboto Slab,helvetica,arial,sans-serif;font-weight:700;position:relative;display:inline-block;padding-bottom:0;margin-top:0;margin-bottom:0;line-height:1.2;font-size:21px;-webkit-flex:1;-ms-flex:1;flex:1;}</style><h4 class="css-134ap8u">Por Alonso Martinez</h4></div><style data-emotion-css="1wof5cd">.css-1wof5cd{font-weight:400;margin-top:4px;}</style><p class="css-1wof5cd">Periodista.
# Correo: alonso[arroba]delfino.cr</p></div></div></a></div><div class="css-pyeond"></div><style data-emotion-css="tr1cr6">.css-tr1cr6{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;padding:20px 0;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}</style><div class="css-tr1cr6"><div class="css-z2j2md"><style data-emotion-css="1h4uoha">.css-1h4uoha{font-family:Roboto Slab,helvetica,arial,sans-serif;font-weight:700;position:relative;display:inline-block;padding-bottom:6px;margin-top:0;margin-bottom:0;line-height:1.2;font-size:20px;margin-right:20px;min-width:150px;}@media (max-width:768px){.css-1h4uoha{margin-right:0px;}}</style><h6 class="css-1h4uoha">Temas relacionados</h6></div><div class="css-0"><style data-emotion-css="zn2zpc">.css-zn2zpc{background-color:black;padding:8px 12px;border-radius:4px;margin:5px;font-size:12px;text-transform:uppercase;color:white;display:inline-block;cursor:pointer;-webkit-transition:background-color 0.3s ease;transition:background-color 0.3s ease;}.css-zn2zpc:hover{background-color:#FF0100;}@media (max-width:768px){.css-zn2zpc{margin:2px;font-size:11px;}}</style><span class="css-zn2zpc">inundaciones</span><span class="css-zn2zpc">Comisión Nacional de Emergencias</span><span class="css-zn2zpc">CNE</span><span class="css-zn2zpc">lluvias</span></div></div><style data-emotion-css="1bq9cq">.css-1bq9cq{width:100%;padding:20px 0 0 0;box-sizing:border-box;}</style><div class="css-1bq9cq"><style data-emotion-css="1aiz7dm">.css-1aiz7dm{border-bottom:2px solid #111111;}</style><div class="css-1aiz7dm"><div class="css-z2j2md"><style data-emotion-css="r8syd7">.css-r8syd7{font-family:Roboto Slab,helvetica,arial,sans-serif;font-weight:700;position:relative;display:inline-block;padding-bottom:6px;margin-top:0;margin-bottom:0;line-height:1.2;font-size:20px;}@media (max-width:768px){.css-r8syd7{font-size:18px;}}</style><h6 class="css-r8syd7">Artículos Recomendados</h6></div></div><style data-emotion-css="9h6jb9">.css-9h6jb9{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}</style><div class="css-9h6jb9"><style data-emotion-css="j4zasr">.css-j4zasr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;max-width:310px;margin-right:30px;width:100%;}@media (max-width:768px){.css-j4zasr{max-width:100%;margin-right:0;}}</style><div class="css-j4zasr"><style data-emotion-css="13xjlpg">.css-13xjlpg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-flex-direction:row-reverse !important;-ms-flex-direction:row-reverse !important;flex-direction:row-reverse !important;width:100%;padding:20px 0;}.css-13xjlpg .dotSeparator{color:#aaaaaa;display:none;}.css-13xjlpg .category a:hover{-webkit-text-decoration:none !important;text-decoration:none !important;}.css-13xjlpg .img{height:80px;width:120px;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;margin-right:0;margin-left:10px;}@media (max-width:375px){.css-13xjlpg .img{margin-bottom:10px;}}.css-13xjlpg .title{margin-bottom:7px;}.css-13xjlpg .author{margin-bottom:3px;}.css- ...

# %% [markdown]
# ### Separamos las oraciones del codigo HTML usando expresiones regulares (filtrado de contenido)

# %%
# importamos la biblioteca de expresiones regulares
import re

# copiamos el texto a una variable string
input_string = str(text)

# filtramos cada uno de los tokens dentro de las <> para que solo queden las oraciones
# NOTA: no podia ser solo r'<[^<>]+>' como se tenia al inicio ya que contaba el codigo
# en javascript que no se ocupaba
output_string = re.sub(r'<script.*?>.*?</script>', ' ', input_string, flags=re.DOTALL)
output_string = re.sub(r'<style .*?>.*?</style>', ' ', output_string, flags=re.DOTALL)
output_string = re.sub(r'<[^<>]+>', ' ', output_string)

# se imprime el string con solo las oraciones de la noticia del html original
print(output_string)
# Out:
#              Lluvias del fin de semana provocaron afectaciones en Golfito, Esparza, Quepos y Garabito - Delfino.cr                                                      Iniciar Sesión                             Acceso rápido:      Última hora      Asamblea      La Jornada       Super Reporte                                Hoy           Lluvias del fin de semana provocaron afectaciones en Golfito, Esparza, Quepos y Garabito       4 Set, 2023    •   2:12 PM     Foto:  Con fines ilustrativos                                                       En total se presentaron 33 eventos de emergencia debido a lluvias del fin de semana.
#  La  Comisión Nacional de Emergencias  (CNE) informó que las lluvias del fin de semana dejaron inundaciones en parte de la vertiente del pacífico, siendo los cantones de Golfito, Esparza, Quepos y Garabito los de más afectación.
#  La mayoría de las emergencias atendidas por los comités de emergencia se debieron al desbordamiento de quebradas y alcantarillas que provocaron la llegada de agua a las viviendas y locales. En total se presentaron  33 eventos.
#  Según indicó el presidente ejecutivo de la CNE,  Alejandro Picado Eduarte,  otras de las afectaciones fueron provocadas por las altas mareas presentadas en Puntarenas donde se reportaron incidentes en los cantones de Esparza en Caldera; Quepos en El Cocal; y Golfito en Pavones.
#  El jerarca recordó que, de acuerdo con el Instituto Meteorológico Nacional (IMN), el país se encuentra  en la etapa más intensa de la época lluviosa , por lo que es común que se den lluvias súbitas que desencadenen cabezas de agua y deslizamientos en algunas zonas del territorio nacional.
#                      Por Alonso Martinez    Periodista.
# Correo: alonso[arroba]delfino.cr            Temas relacionados     inundaciones  Comisión Nacional de Emergencias  CNE  lluvias          Artículos Recomendados                 CNE reportó 42 incidentes de inundación por lluvias durante el fin de semana       Andrea Mora   •        21 Ago, 2023    •   12:34 PM                 CNE declara alerta amarilla en todo el país por onda tropical número 28     Luis Manuel Madrigal   •       11 Ago, 2023    •   6:31 PM                CNE pide precaución pues tiene previstas más cabezas de agua en el río Aguas Zarcas     Andrea Mora   •       25 Jul, 2023    •   1:30 PM                CNE: Deslizamiento en Aguas Zarcas es el más grande en la historia moderna de la Zona Norte     Alonso Martinez   •       20 Jul, 2023    •   5:46 PM                Fuertes lluvias provocan inundaciones en Alajuela, Pérez Zeledón, Golfito y La Unión     Andrea Mora   •       18 Jul, 2023    •   11:27 AM                 Usted merece informarse rápido y gratuito      De martes a viernes le contamos las noticias más importantes en nuestro reporte de forma honesta y sencilla.     Correo Electrónico       Apuntarme   En cualquier momento puede salirse de la lista de correos.         Hoy   Lo   +  leído                 Hoy           El Tribunal Supremo de México despenaliza el aborto a nivel federal   Informaron que el sistema jurídico que penaliza el aborto es "inconstitucional", puesto que "viola los Derechos Humanos de las mujeres y personas con capacidad de gestar".     Europa Press   •       6 Set, 2023    •   3:34 PM                Hoy          Chaves: “se puede sacar a Costa Rica de la lista negra sin cometer ese enorme error”  Presidente no descartó vetar ley que pretende sacar a Costa Rica de la lista de países no cooperantes en materia fiscal de la Unión Europea.     Sebastian May Grosser   •       6 Set, 2023    •   3:25 PM               Hoy          MEP da marcha atrás y realizará etapa nacional del Festival Estudiantil de las Artes  En principio el MEP señaló que en 2023 hubo un recorte en los fondos generales y que por esta razón el evento sería cancelado.      Alonso Martinez   •       6 Set, 2023    •   2:59 PM               Hoy          Salud emite alerta sanitaria por aumento de casos de dengue en el país  El Ministerio de Salud emitió, este miércoles, una nueva alerta sanitaria debido al aumento de casos de dengue que ha registrado el país en las últimas semanas.     Andrea Mora   •       6 Set, 2023    •   2:30 PM               Hoy          Confianza del consumidor se recuperó en agosto  Un 37% de las personas sigue opinando de forma negativa sobre las políticas económicas del Gobierno.     Sebastian May Grosser   •       6 Set, 2023    •   1:02 PM                   Por sólo $56 anual obtenga todos los beneficios del contenido D  +      Suscribirme a D+

# %% [markdown]
# ### Para seperarlos por oraciones usamos la expresion regular: r'.*.' (identificación de oraciones)

# %%
expresion = r'.*.'
tokens = re.findall(expresion, output_string)
print(tokens)
print('Cantidad de oraciones: ', len(tokens))
# Out:
# ['             Lluvias del fin de semana provocaron afectaciones en Golfito, Esparza, Quepos y Garabito - Delfino.cr                                                      Iniciar Sesión                             Acceso rápido:      Última hora      Asamblea      La Jornada       Super Reporte                                Hoy           Lluvias del fin de semana provocaron afectaciones en Golfito, Esparza, Quepos y Garabito       4 Set, 2023  \xa0 • \xa0 2:12 PM     Foto:  Con fines ilustrativos                                                       En total se presentaron 33 eventos de emergencia debido a lluvias del fin de semana. ', ' La \xa0Comisión Nacional de Emergencias  (CNE) informó que las lluvias del fin de semana dejaron inundaciones en parte de la vertiente del pacífico, siendo los cantones de Golfito, Esparza, Quepos y Garabito los de más afectación. ', ' La mayoría de las emergencias atendidas por los comités de emergencia se debieron al desbordamiento de quebradas y alcantarillas que provocaron la llegada de agua a las viviendas y locales. En total se presentaron  33 eventos.  ', ' Según indicó el presidente ejecutivo de la CNE,\xa0 Alejandro Picado Eduarte,  otras de las afectaciones fueron provocadas por las altas mareas presentadas en Puntarenas donde se reportaron incidentes en los cantones de Esparza en Caldera; Quepos en El Cocal; y Golfito en Pavones. ', ' El jerarca recordó que, de acuerdo con el Instituto Meteorológico Nacional (IMN), el país se encuentra  en la etapa más intensa de la época lluviosa , por lo que es común que se den lluvias súbitas que desencadenen cabezas de agua y deslizamientos en algunas zonas del territorio nacional. ', '                     Por Alonso Martinez    Periodista.\r', 'Correo: alonso[arroba]delfino.cr            Temas relacionados     inundaciones  Comisión Nacional de Emergencias  CNE  lluvias          Artículos Recomendados                 CNE reportó 42 incidentes de inundación por lluvias durante el fin de semana       Andrea Mora \xa0 • \xa0      21 Ago, 2023  \xa0 • \xa0 12:34 PM                 CNE declara alerta amarilla en todo el país por onda tropical número 28     Luis Manuel Madrigal \xa0 • \xa0     11 Ago, 2023  \xa0 • \xa0 6:31 PM                CNE pide precaución pues tiene previstas más cabezas de agua en el río Aguas Zarcas     Andrea Mora \xa0 • \xa0     25 Jul, 2023  \xa0 • \xa0 1:30 PM                CNE: Deslizamiento en Aguas Zarcas es el más grande en la historia moderna de la Zona Norte     Alonso Martinez \xa0 • \xa0     20 Jul, 2023  \xa0 • \xa0 5:46 PM                Fuertes lluvias provocan inundaciones en Alajuela, Pérez Zeledón, Golfito y La Unión     Andrea Mora \xa0 • \xa0     18 Jul, 2023  \xa0 • \xa0 11:27 AM                 Usted merece informarse rápido y gratuito      De martes a viernes le contamos las noticias más importantes en nuestro reporte de forma honesta y sencilla.     Correo Electrónico       Apuntarme   En cualquier momento puede salirse de la lista de correos.         Hoy   Lo   +  leído                 Hoy           El Tribunal Supremo de México despenaliza el aborto a nivel federal   Informaron que el sistema jurídico que penaliza el aborto es "inconstitucional", puesto que "viola los Derechos Humanos de las mujeres y personas con capacidad de gestar".     Europa Press \xa0 • \xa0     6 Set, 2023  \xa0 • \xa0 3:34 PM                Hoy          Chaves: “se puede sacar a Costa Rica de la lista negra sin cometer ese enorme error”  Presidente no descartó vetar ley que pretende sacar a Costa Rica de la lista de países no cooperantes en materia fiscal de la Unión Europea.     Sebastian May Grosser \xa0 • \xa0     6 Set, 2023  \xa0 • \xa0 3:25 PM               Hoy          MEP da marcha atrás y realizará etapa nacional del Festival Estudiantil de las Artes  En principio el MEP señaló que en 2023 hubo un recorte en los fondos generales y que por esta razón el evento sería cancelado.\xa0     Alonso Martinez \xa0 • \xa0      ...
# Cantidad de oraciones:  7

# %% [markdown]
# ### Para separarlos por palabras usamos la expresion regular: r'\w+' (identificación de tokens)

# %%
expresion = r'\w+'
tokens = re.findall(expresion, output_string)
print(tokens)
print('Cantidad de palabras: ', len(tokens))
# Out:
# ['Lluvias', 'del', 'fin', 'de', 'semana', 'provocaron', 'afectaciones', 'en', 'Golfito', 'Esparza', 'Quepos', 'y', 'Garabito', 'Delfino', 'cr', 'Iniciar', 'Sesión', 'Acceso', 'rápido', 'Última', 'hora', 'Asamblea', 'La', 'Jornada', 'Super', 'Reporte', 'Hoy', 'Lluvias', 'del', 'fin', 'de', 'semana', 'provocaron', 'afectaciones', 'en', 'Golfito', 'Esparza', 'Quepos', 'y', 'Garabito', '4', 'Set', '2023', '2', '12', 'PM', 'Foto', 'Con', 'fines', 'ilustrativos', 'En', 'total', 'se', 'presentaron', '33', 'eventos', 'de', 'emergencia', 'debido', 'a', 'lluvias', 'del', 'fin', 'de', 'semana', 'La', 'Comisión', 'Nacional', 'de', 'Emergencias', 'CNE', 'informó', 'que', 'las', 'lluvias', 'del', 'fin', 'de', 'semana', 'dejaron', 'inundaciones', 'en', 'parte', 'de', 'la', 'vertiente', 'del', 'pacífico', 'siendo', 'los', 'cantones', 'de', 'Golfito', 'Esparza', 'Quepos', 'y', 'Garabito', 'los', 'de', 'más', 'afectación', 'La', 'mayoría', 'de', 'las', 'emergencias', 'atendidas', 'por', 'los', 'comités', 'de', 'emergencia', 'se', 'debieron', 'al', 'desbordamiento', 'de', 'quebradas', 'y', 'alcantarillas', 'que', 'provocaron', 'la', 'llegada', 'de', 'agua', 'a', 'las', 'viviendas', 'y', 'locales', 'En', 'total', 'se', 'presentaron', '33', 'eventos', 'Según', 'indicó', 'el', 'presidente', 'ejecutivo', 'de', 'la', 'CNE', 'Alejandro', 'Picado', 'Eduarte', 'otras', 'de', 'las', 'afectaciones', 'fueron', 'provocadas', 'por', 'las', 'altas', 'mareas', 'presentadas', 'en', 'Puntarenas', 'donde', 'se', 'reportaron', 'incidentes', 'en', 'los', 'cantones', 'de', 'Esparza', 'en', 'Caldera', 'Quepos', 'en', 'El', 'Cocal', 'y', 'Golfito', 'en', 'Pavones', 'El', 'jerarca', 'recordó', 'que', 'de', 'acuerdo', 'con', 'el', 'Instituto', 'Meteorológico', 'Nacional', 'IMN', 'el', 'país', 'se', 'encuentra', 'en', 'la', 'etapa', 'más', 'intensa', 'de', 'la', 'época', 'lluviosa', 'por', 'lo', 'que', 'es', 'común', 'que', 'se', 'den', 'lluvias', 'súbitas', 'que', 'desencadenen', 'cabezas', 'de', 'agua', 'y', 'deslizamientos', 'en', 'algunas', 'zonas', 'del', 'territorio', 'nacional', 'Por', 'Alonso', 'Martinez', 'Periodista', 'Correo', 'alonso', 'arroba', 'delfino', 'cr', 'Temas', 'relacionados', 'inundaciones', 'Comisión', 'Nacional', 'de', 'Emergencias', 'CNE', 'lluvias', 'Artículos', 'Recomendados', 'CNE', 'reportó', '42', 'incidentes', 'de', 'inundación', 'por', 'lluvias', 'durante', 'el', 'fin', 'de', 'semana', 'Andrea', 'Mora', '21', 'Ago', '2023', '12', '34', 'PM', 'CNE', 'declara', 'alerta', 'amarilla', 'en', 'todo', 'el', 'país', 'por', 'onda', 'tropical', 'número', '28', 'Luis', 'Manuel', 'Madrigal', '11', 'Ago', '2023', '6', '31', 'PM', 'CNE', 'pide', 'precaución', 'pues', 'tiene', 'previstas', 'más', 'cabezas', 'de', 'agua', 'en', 'el', 'río', 'Aguas', 'Zarcas', 'Andrea', 'Mora', '25', 'Jul', '2023', '1', '30', 'PM', 'CNE', 'Deslizamiento', 'en', 'Aguas', 'Zarcas', 'es', 'el', 'más', 'grande', 'en', 'la', 'historia', 'moderna', 'de', 'la', 'Zona', 'Norte', 'Alonso', 'Martinez', '20', 'Jul', '2023', '5', '46', 'PM', 'Fuertes', 'lluvias', 'provocan', 'inundaciones', 'en', 'Alajuela', 'Pérez', 'Zeledón', 'Golfito', 'y', 'La', 'Unión', 'Andrea', 'Mora', '18', 'Jul', '2023', '11', '27', 'AM', 'Usted', 'merece', 'informarse', 'rápido', 'y', 'gratuito', 'De', 'martes', 'a', 'viernes', 'le', 'contamos', 'las', 'noticias', 'más', 'importantes', 'en', 'nuestro', 'reporte', 'de', 'forma', 'honesta', 'y', 'sencilla', 'Correo', 'Electrónico', 'Apuntarme', 'En', 'cualquier', 'momento', 'puede', 'salirse', 'de', 'la', 'lista', 'de', 'correos', 'Hoy', 'Lo', 'leído', 'Hoy', 'El', 'Tribunal', 'Supremo', 'de', 'México', 'despenaliza', 'el', 'aborto', 'a', 'nivel', 'federal', 'Informaron', 'que', 'el', 'sistema', 'jurídico', 'que', 'penaliza', 'el', 'aborto', 'es', 'inconstitucional', 'puesto', 'que', 'viola', 'los', 'Derechos', 'Humanos', 'de', 'las', 'mujeres', 'y', 'personas', 'con', 'capacidad', 'de', 'gestar', 'Europa', 'Press', '6', 'Set', '2023', '3', '34', 'PM', 'Hoy', ...
# Cantidad de palabras:  639

# %% [markdown]
# ### Para contar las palabras diferentes y su frecuencia (análisis de frecuencia)

# %%
def contar_palabras_distintas(tokens):
  palabra = set(tokens)
  frecuencia = {}
  for value in palabra:
    frecuencia[value] = tokens.count(value)

  return frecuencia
palabras_contador = contar_palabras_distintas(tokens)
print(palabras_contador)
# Out:
# {'Fuertes': 1, 'ilustrativos': 1, 'fondos': 1, 'semanas': 1, '2': 3, 'le': 1, 'debido': 2, 'informarse': 1, 'Humanos': 1, 'comités': 1, 'Un': 1, 'Iniciar': 1, 'dengue': 2, 'parte': 1, 'provocaron': 3, 'Lluvias': 2, 'principio': 1, 'amarilla': 1, 'Artes': 1, 'Luis': 1, 'emite': 1, 'Grosser': 2, 'aumento': 2, 'se': 8, 'pide': 1, 'Press': 1, 'federal': 1, 'emergencias': 1, 'Sebastian': 2, 'enorme': 1, 'PM': 10, 'Jul': 3, '56': 1, 'despenaliza': 1, 'Zona': 1, 'todo': 1, '18': 1, 'hubo': 1, 'MEP': 2, 'martes': 1, 'inundación': 1, '37': 1, 'reporte': 1, 'Caldera': 1, 'cr': 2, 'Martinez': 3, 'tropical': 1, 'Instituto': 1, 'reportó': 1, 'inundaciones': 3, 'un': 1, 'Pavones': 1, 'sólo': 1, 'río': 1, 'Puntarenas': 1, 'casos': 2, 'presentadas': 1, 'razón': 1, 'que': 13, 'por': 7, '46': 1, 'nivel': 1, 'AM': 1, 'hora': 1, 'común': 1, 'fin': 5, 'debieron': 1, 'todos': 1, 'Manuel': 1, 'personas': 2, 'lluvias': 6, 'registrado': 1, 'Chaves': 1, 'reportaron': 1, 'etapa': 2, 'total': 2, 'historia': 1, 'Alejandro': 1, 'inconstitucional': 1, 'encuentra': 1, 'Costa': 2, 'y': 13, 'realizará': 1, 'Gobierno': 1, '59': 1, 'Comisión': 2, 'penaliza': 1, '1': 2, 'cometer': 1, 'De': 1, 'informó': 1, 'últimas': 1, 'nuestro': 1, 'miércoles': 1, 'México': 1, 'época': 1, 'Emergencias': 2, 'fueron': 1, 'obtenga': 1, 'viviendas': 1, '12': 2, 'agua': 3, 'algunas': 1, 'zonas': 1, 'Pérez': 1, 'Informaron': 1, 'Lo': 1, 'los': 7, 'Jornada': 1, 'Andrea': 4, 'Esparza': 4, 'donde': 1, 'fines': 1, 'gratuito': 1, 'Reporte': 1, 'Garabito': 3, 'delfino': 1, 'La': 4, 'IMN': 1, 'Salud': 2, 'contenido': 1, 'súbitas': 1, '25': 2, 'afectación': 1, 'desencadenen': 1, 'Unión': 2, 'da': 1, 'en': 22, 'locales': 1, '5': 1, 'ley': 1, '02': 1, 'Derechos': 1, 'Nacional': 3, 'dejaron': 1, 'rápido': 2, 'negativa': 1, 'Artículos': 1, 'Europa': 1, 'alerta': 3, 'presidente': 1, 'viola': 1, 'intensa': 1, 'otras': 1, 'declara': 1, 'Set': 6, 'salirse': 1, 'sería': 1, 'recuperó': 1, 'alonso': 1, 'previstas': 1, 'atendidas': 1, 'momento': 1, 'lista': 3, 'anual': 1, 'arroba': 1, 'precaución': 1, 'con': 2, 'vetar': 1, 'Zeledón': 1, 'sacar': 2, 'económicas': 1, 'onda': 1, '42': 1, 'Sesión': 1, 'territorio': 1, 'pretende': 1, '21': 1, 'Meteorológico': 1, '34': 2, 'Estudiantil': 1, 'Madrigal': 1, 'Eduarte': 1, 'ha': 1, '11': 2, 'países': 1, 'jurídico': 1, 'honesta': 1, 'generales': 1, 'ejecutivo': 1, 'D': 2, 'Confianza': 1, 'mayoría': 1, 'Con': 1, 'cualquier': 1, 'leído': 1, 'señaló': 1, 'puesto': 1, 'nacional': 2, 'Por': 2, 'del': 10, 'Rica': 2, 'a': 7, 'provocan': 1, 'es': 3, 'Usted': 1, 'materia': 1, 'capacidad': 1, 'Presidente': 1, 'beneficios': 1, 'número': 1, 'tiene': 1, 'Asamblea': 1, 'políticas': 1, 'marcha': 1, 'Ministerio': 1, 'Super': 1, 'sanitaria': 2, 'recordó': 1, 'merece': 1, 'Tribunal': 1, 'eventos': 2, 'emitió': 1, 'Golfito': 5, 'lo': 1, 'Recomendados': 1, 'relacionados': 1, 'cooperantes': 1, 'grande': 1, 'sobre': 1, 'fiscal': 1, 'Según': 1, 'semana': 5, 'Foto': 1, 'siendo': 1, '4': 1, 'forma': 2, '28': 1, 'Electrónico': 1, 'llegada': 1, 'En': 4, 'Mora': 4, 'contamos': 1, 'durante': 1, 'país': 4, 'emergencia': 2, 'Delfino': 1, 'Deslizamiento': 1, 'CNE': 7, 'una': 1, 'correos': 1, 'consumidor': 1, 'Cocal': 1, 'Picado': 1, 'cabezas': 2, 'atrás': 1, 'deslizamientos': 1, 'no': 2, 'ese': 1, '33': 2, 'descartó': 1, '6': 6, 'Ago': 2, 'provocadas': 1, 'nueva': 1, 'Suscribirme': 1, '2023': 12, 'lluviosa': 1, 'jerarca': 1, 'Alajuela': 1, 'sistema': 1, 'vertiente': 1, 'Correo': 2, 'Zarcas': 2, 'quebradas': 1, 'evento': 1, 'alcantarillas': 1, 'mareas': 1, 'indicó': 1, 'Aguas': 2, 'gestar': 1, 'Última': 1, 'sin': 1, 'Europea': 1, 'viernes': 1, 'afectaciones': 3, 'Temas': 1, '30': 2, 'sigue': 1, 'esta': 1, 'Norte': 1, 'la': 11, 'Hoy': 7, 'altas': 1, 'Quepos': 4, 'mujeres': 1, 'recorte': 1, 'error': 1, 'presentaron': 2, 'las': 11, 'Periodista': 1, 'puede': 2, 'opinando': 1, 'May': 2, 'desbordamiento': 1, 'importantes': 1, 'negra': 1, 'aborto': 2, 'moderna': 1, '31': 1, 'El': 4, 'agosto': 1, 'noticia ...

# %% [markdown]
# ### Se grafica la frecuencia de las palabras usando un grafico de barras

# %%
import matplotlib.pyplot as plt
import numpy as np

# obtenemos la lista de palabras
palabras = list(palabras_contador.keys())

# obtenemos la cantidad que se usa la palabra
cantidad = list(palabras_contador.values())

# valores para el eje x
x = np.arange(len(palabras))

# crea una grafica de barras
plt.bar(x, cantidad, color="green")

# nombramos los ejes en x y en y
plt.xlabel("Palabras")
plt.ylabel("Cantidad de veces usada")

# titulo de la grafica
plt.title("Histograma de la frecuencia de palabras en una noticia")

# mostrar el grafico
plt.show()

# %% [markdown]
# ### Para ver las palabras mas usadas de manera ordenada de mayor uso a menor uso

# %%
# ordenamos de mayor a menor
sorted_palabras_contador = dict(sorted(palabras_contador.items(), key=lambda item: item[1], reverse=True))

# obtenemos las palabras con mayor frecuencia y las frecuencias de las respectivas palabras
top_palabras = list(sorted_palabras_contador.keys())[:]
top_frequencias = [sorted_palabras_contador[word] for word in top_palabras]

# se define el eje x
x = np.arange(len(top_palabras))
print(len(x))
# se crea la grafica de barras
plt.bar(x, top_frequencias, color="green")

# rotamos las palabras para que se puedan leer mejor
plt.xticks(x, top_palabras, rotation=45)

# se titula la grafica y los ejes
plt.xlabel("Palabras")
plt.ylabel("Cantidad de veces usada")
plt.title("Palabras más frecuentes en una noticia")

# para mostrar la grafica
plt.show()
# Out:
# 324

# %% [markdown]
# ### Para ver el top 10 de las palabras mas usadas en una noticia

# %%
# ordenamos de mayor a menor
sorted_palabras_contador = dict(sorted(palabras_contador.items(), key=lambda item: item[1], reverse=True))

# obtenemos las palabras con mayor frecuencia y las frecuencias de las respectivas palabras
top_palabras = list(sorted_palabras_contador.keys())[:10]
top_frequencias = [sorted_palabras_contador[word] for word in top_palabras]

# se define el eje x
x = np.arange(len(top_palabras))

# se crea la grafica de barras
plt.bar(x, top_frequencias, color="green")

# rotamos las palabras para que se puedan leer mejor
plt.xticks(x, top_palabras, rotation=45)

# se titula la grafica y los ejes
plt.xlabel("Palabras")
plt.ylabel("Cantidad de veces usada")
plt.title("Top 10 palabras más frecuentes en una noticia")

# para mostrar la grafica
plt.show()

# %% [markdown]
# ### Para la distribucion Zipf
# Zipf establece que dada una lengua, la frecuencia de aparicion de las distintas palabras de su vocabulario sigue una distribucion que puede aproximarse por:
#
# $P_n \sim 1/n^a$
#
# Tambien se conoce como: "La ley, de manera simple, nos dice que la segunda palabra más usada de un idioma aparecerá la mitad de veces que la palabra más usada, la tercera palabra más usada un tercio de veces que la más usada, la cuarta palabra más usada un cuarto de veces que la más usada, y así sucesivamente."

# %%
# ordenamos de mayor a menor
sorted_palabras_contador = dict(sorted(palabras_contador.items(), key=lambda item: item[1], reverse=True))

# se obtiene la lista de palabras y sus frecuencias ordenadas respectivamente
palabras = list(sorted_palabras_contador.keys())
frecuencias = list(sorted_palabras_contador.values())

# se crea una distribución Zipf
dist_zipf = [frecuencias[0] / (i + 1) for i in range(len(frecuencias))]

# se crea una grafica de barras para la distribución de Zipf
plt.bar(np.arange(len(dist_zipf)), dist_zipf, color="green")

# se titula la grafica y los ejes
plt.xlabel("Palabras (ordenadas por frecuencia)")
plt.ylabel("Frecuencia de Zipf")
plt.title("Distribución de Zipf basada en las frecuencias de palabras")

# muestra la grafica
plt.show()

# %% [markdown]
# ### Bibliografia
# 1.  https://www.madrimasd.org/blogs/matematicas/2019/03/10/146325#:~:text=La%20ley%2C%20de%20manera%20simple,m%C3%A1s%20usada%2C%20y%20as%C3%AD%20sucesivamente.
#
# 2. Daniel Jurafsky, James H. Martin. "Speech and Language Processing An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition".(2019)
